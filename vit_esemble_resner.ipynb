# %% [markdown]
# <a href="https://colab.research.google.com/github/surajonuhu/startuppage/blob/main/vit_esemble_resner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import timm
import wandb
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/archive.zip" -d "/content"
# Out:
# Archive:  /content/drive/MyDrive/archive.zip
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple Scab Leaf/Apple Scab Leaf (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple leaf/Apple leaf (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Apple rust leaf/Apple rust leaf (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf spot/Bell_pepper leaf spot (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Bell_pepper leaf/Bell_pepper leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (11).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Blueberry leaf/Blueberry leaf (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cherry leaf/Cherry leaf (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Corn Gray leaf spot/Corn Gray leaf spot (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Corn Gray leaf spot/Corn Gray leaf spot (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Corn Gray leaf spot/Corn Gray leaf spot (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Cor
8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Early blight leaf/Tomato Early blight leaf (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (11).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato Septoria leaf spot/Tomato Septoria leaf spot (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf bacterial spot/Tomato leaf bacterial spot (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf late blight/Tomato leaf late blight (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf mosaic virus/Tomato leaf mosaic virus (9).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf yellow virus/Tomato leaf yellow virus (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf yellow virus/Tomato leaf yellow virus (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf yellow virus/Tomato leaf yellow virus (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf yellow virus/Tomato leaf yellow virus (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf yellow virus/Tomato leaf yellow virus (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf yellow virus/Tomato leaf yellow virus (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato leaf/Tomato leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato mold leaf/Tomato mold leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato mold leaf/Tomato mold leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato mold leaf/Tomato mold leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato mold leaf/Tomato mold leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato mold leaf/Tomato mold leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/Tomato mold leaf/Tomato mold leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf black rot/grape leaf black rot (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (10).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (11).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (12).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/test/grape leaf/grape leaf (9).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (10).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (11).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (12).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (13).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (14).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (15).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (16).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (17).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (18).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (19).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (20).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (21).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (22).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (23).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (24).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (25).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (26).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (27).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (28).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (29).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (30).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (31).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (32).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (33).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (34).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (35).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf (36).jpg
#   inflating: /content/PlantDoc-Dataset/train/Apple Scab Leaf/Apple Scab Leaf
jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (39).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (4).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (40).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (41).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (42).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (43).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (44).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (45).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (46).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (47).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (48).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (49).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (5).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (50).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (51).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (52).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (53).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (54).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (55).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (56).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (6).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (7).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (8).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf black rot/grape leaf black rot (9).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (1).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (10).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (11).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (12).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (13).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (14).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (15).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (16).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (17).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (18).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (19).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (2).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (20).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (21).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (22).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (23).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (24).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (25).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (26).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (27).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (28).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (29).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (3).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (30).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (31).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (32).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (33).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (34).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (35).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (36).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (37).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (38).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (39).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (4).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (40).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (41).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (42).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (43).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (44).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (45).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (46).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (47).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (48).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (49).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (5).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (50).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (51).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (52).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (53).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (54).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (55).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (56).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (57).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (6).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (7).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (8).jpg
#   inflating: /content/PlantDoc-Dataset/train/grape leaf/grape leaf (9).jpg

# %%
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS_BASE = 10  # for base models
EPOCHS_ENSEMBLE = 10
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATA_DIR = "/content/PlantDoc-Dataset"  # expects dataset/train and dataset/val
MODEL_DIR = "checkpoints"
os.makedirs(MODEL_DIR, exist_ok=True)
wandb.login(key="7901d254978ef4af4b881a72b10eda5eb36a4bb3")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
train_tfms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225]),
])

val_tfms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225]),
])

train_ds = datasets.ImageFolder(f"{DATA_DIR}/train", transform=train_tfms)
val_ds   = datasets.ImageFolder(f"{DATA_DIR}/test", transform=val_tfms)
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

NUM_CLASSES = len(train_ds.classes)
print("Classes:", train_ds.classes)
# Out:
# Classes: ['Apple Scab Leaf', 'Apple leaf', 'Apple rust leaf', 'Bell_pepper leaf', 'Bell_pepper leaf spot', 'Blueberry leaf', 'Cherry leaf', 'Corn Gray leaf spot', 'Corn leaf blight', 'Corn rust leaf', 'Peach leaf', 'Potato leaf early blight', 'Potato leaf late blight', 'Raspberry leaf', 'Soyabean leaf', 'Squash Powdery mildew leaf', 'Strawberry leaf', 'Tomato Early blight leaf', 'Tomato Septoria leaf spot', 'Tomato leaf', 'Tomato leaf bacterial spot', 'Tomato leaf late blight', 'Tomato leaf mosaic virus', 'Tomato leaf yellow virus', 'Tomato mold leaf', 'grape leaf', 'grape leaf black rot']

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, name, epochs):
    best_acc = 0
    for epoch in range(epochs):
        # Train
        model.train()
        running_loss, correct = 0.0, 0
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels)

        train_acc = correct.double() / len(train_loader.dataset)
        train_loss = running_loss / len(train_loader.dataset)

        # Validate
        model.eval()
        val_loss, val_correct = 0.0, 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                _, preds = torch.max(outputs, 1)
                val_correct += torch.sum(preds == labels)

        val_acc = val_correct.double() / len(val_loader.dataset)
        val_loss /= len(val_loader.dataset)

        # Log metrics to wandb
        wandb.log({
            f"{name}_train_loss": train_loss,
            f"{name}_train_acc": train_acc.item(),
            f"{name}_val_loss": val_loss,
            f"{name}_val_acc": val_acc.item(),
            "epoch": epoch+1
        })

        print(f"{name} Epoch [{epoch+1}/{epochs}] "
              f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} "
              f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")

        # Save best
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), f"{MODEL_DIR}/{name}.pth")
    return model

# %%
def train_base_models():
    criterion = nn.CrossEntropyLoss()

    # ViT
    vit = timm.create_model('vit_base_patch16_224', pretrained=True, num_classes=NUM_CLASSES).to(DEVICE)
    opt = optim.Adam(vit.parameters(), lr=1e-4)
    train_model(vit, train_loader, val_loader, criterion, opt, "vit_model", EPOCHS_BASE)

    # EfficientNet
    eff = timm.create_model('efficientnet_b0', pretrained=True, num_classes=NUM_CLASSES).to(DEVICE)
    opt = optim.Adam(eff.parameters(), lr=1e-4)
    train_model(eff, train_loader, val_loader, criterion, opt, "effnet_model", EPOCHS_BASE)

    # ResNet50
    res = models.resnet50(pretrained=True)
    res.fc = nn.Linear(res.fc.in_features, NUM_CLASSES)
    res = res.to(DEVICE)
    opt = optim.Adam(res.parameters(), lr=1e-4)
    train_model(res, train_loader, val_loader, criterion, opt, "resnet_model", EPOCHS_BASE)

# %%
class EnsembleNet(nn.Module):
    def __init__(self, num_classes):
        super(EnsembleNet, self).__init__()

        # ViT
        self.vit = timm.create_model('vit_base_patch16_224', pretrained=False, num_classes=num_classes)
        self.vit.load_state_dict(torch.load(f"{MODEL_DIR}/vit_model.pth"))
        self.vit.head = nn.Identity()
        vit_dim = self.vit.num_features

        # EfficientNet
        self.eff = timm.create_model('efficientnet_b0', pretrained=False, num_classes=num_classes)
        self.eff.load_state_dict(torch.load(f"{MODEL_DIR}/effnet_model.pth"))
        self.eff.classifier = nn.Identity()
        eff_dim = self.eff.num_features

        # ResNet
        self.res = models.resnet50(pretrained=False)
        self.res.fc = nn.Linear(self.res.fc.in_features, num_classes)
        self.res.load_state_dict(torch.load(f"{MODEL_DIR}/resnet_model.pth"))
        self.res.fc = nn.Identity()
        res_dim = 2048

        # Freeze
        for net in [self.vit, self.eff, self.res]:
            for p in net.parameters():
                p.requires_grad = False

        # Classifier
        concat_dim = vit_dim + eff_dim + res_dim
        self.fc = nn.Sequential(
            nn.ReLU(),
            nn.Linear(concat_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
            f1 = self.vit(x)
            f2 = self.eff(x)
            f3 = self.res(x)
            combined = torch.cat((f1, f2, f3), dim=1)
            return self.fc(combined)

# %%
def evaluate_model(model, loader, class_names):
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    cm = confusion_matrix(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

    # Log to wandb
    wandb.log({
        "confusion_matrix": wandb.plot.confusion_matrix(
            y_true=y_true,
            preds=y_pred,
            class_names=class_names
        ),
        "classification_report": report
    })

    print(classification_report(y_true, y_pred, target_names=class_names))

# %%
if __name__ == "__main__":
    wandb.init(project="plant-disease-ensemble", name="vit_eff_resnet_ensemble")

    # Train base models (only once, comment out later if already trained)
    train_base_models()

    # Ensemble training
    ensemble = EnsembleNet(NUM_CLASSES).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(ensemble.fc.parameters(), lr=1e-4)

    train_model(ensemble, train_loader, val_loader, criterion, optimizer, "ensemble_model", EPOCHS_ENSEMBLE)

    # Evaluate ensemble
    evaluate_model(ensemble, val_loader, train_ds.classes)

    wandb.finish()
# Out:
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/wandb/run-20250914_175944-2r3npx5t</code>
# Syncing run <strong><a href='https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble/runs/2r3npx5t' target="_blank">vit_eff_resnet_ensemble</a></strong> to <a href='https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble' target="_blank">https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble</a>
#  View run at <a href='https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble/runs/2r3npx5t' target="_blank">https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble/runs/2r3npx5t</a>
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# vit_model Epoch [1/10] Train Loss: 2.0329 Acc: 0.3959 Val Loss: 1.2844 Acc: 0.6186
# vit_model Epoch [2/10] Train Loss: 0.8873 Acc: 0.7094 Val Loss: 0.9823 Acc: 0.6314
# vit_model Epoch [3/10] Train Loss: 0.5100 Acc: 0.8217 Val Loss: 1.2196 Acc: 0.6229
# vit_model Epoch [4/10] Train Loss: 0.4678 Acc: 0.8394 Val Loss: 1.3312 Acc: 0.6017
# vit_model Epoch [5/10] Train Loss: 0.2635 Acc: 0.9167 Val Loss: 1.4244 Acc: 0.6568
# vit_model Epoch [6/10] Train Loss: 0.2569 Acc: 0.9154 Val Loss: 1.4822 Acc: 0.5805
# vit_model Epoch [7/10] Train Loss: 0.2112 Acc: 0.9348 Val Loss: 1.6612 Acc: 0.5890
# vit_model Epoch [8/10] Train Loss: 0.1586 Acc: 0.9478 Val Loss: 1.5646 Acc: 0.6229
# vit_model Epoch [9/10] Train Loss: 0.1286 Acc: 0.9547 Val Loss: 1.7445 Acc: 0.5593
# vit_model Epoch [10/10] Train Loss: 0.1815 Acc: 0.9426 Val Loss: 1.5874 Acc: 0.6568
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# effnet_model Epoch [1/10] Train Loss: 3.0709 Acc: 0.1904 Val Loss: 2.6455 Acc: 0.2754
# effnet_model Epoch [2/10] Train Loss: 1.5502 Acc: 0.5445 Val Loss: 2.0619 Acc: 0.3856
# effnet_model Epoch [3/10] Train Loss: 0.9809 Acc: 0.7137 Val Loss: 1.7944 Acc: 0.5042
# effnet_model Epoch [4/10] Train Loss: 0.6222 Acc: 0.8329 Val Loss: 1.6683 Acc: 0.5339
# effnet_model Epoch [5/10] Train Loss: 0.4436 Acc: 0.8851 Val Loss: 1.6243 Acc: 0.5508
# effnet_model Epoch [6/10] Train Loss: 0.2952 Acc: 0.9318 Val Loss: 1.5604 Acc: 0.5763
# effnet_model Epoch [7/10] Train Loss: 0.2244 Acc: 0.9503 Val Loss: 1.5865 Acc: 0.5932
# effnet_model Epoch [8/10] Train Loss: 0.1849 Acc: 0.9607 Val Loss: 1.6126 Acc: 0.5847
# effnet_model Epoch [9/10] Train Loss: 0.1402 Acc: 0.9750 Val Loss: 1.6083 Acc: 0.5890
# effnet_model Epoch [10/10] Train Loss: 0.1154 Acc: 0.9780 Val Loss: 1.6211 Acc: 0.5975
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00,
#        Corn Gray leaf spot       0.11      0.25      0.15         4
#           Corn leaf blight       0.62      0.42      0.50        12
#             Corn rust leaf       1.00      0.90      0.95        10
#                 Peach leaf       1.00      0.89      0.94         9
#   Potato leaf early blight       0.44      0.50      0.47         8
#    Potato leaf late blight       0.60      0.38      0.46         8
#             Raspberry leaf       0.70      1.00      0.82         7
#              Soyabean leaf       0.80      0.50      0.62         8
# Squash Powdery mildew leaf       1.00      0.83      0.91         6
#            Strawberry leaf       1.00      1.00      1.00         8
#   Tomato Early blight leaf       0.62      0.56      0.59         9
#  Tomato Septoria leaf spot       0.59      0.91      0.71        11
#                Tomato leaf       0.75      0.38      0.50         8
# Tomato leaf bacterial spot       0.33      0.22      0.27         9
#    Tomato leaf late blight       0.71      1.00      0.83        10
#   Tomato leaf mosaic virus       1.00      0.20      0.33        10
#   Tomato leaf yellow virus       0.71      0.83      0.77         6
#           Tomato mold leaf       0.31      0.83      0.45         6
#                 grape leaf       0.92      1.00      0.96        12
#       grape leaf black rot       1.00      0.88      0.93         8
#
#                   accuracy                           0.70       236
#                  macro avg       0.73      0.69      0.68       236
#               weighted avg       0.75      0.70      0.70       236
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>effnet_model_train_acc</td><td>▁▄▆▇▇█████</td></tr><tr><td>effnet_model_train_loss</td><td>█▄▃▂▂▁▁▁▁▁</td></tr><tr><td>effnet_model_val_acc</td><td>▁▃▆▇▇█████</td></tr><tr><td>effnet_model_val_loss</td><td>█▄▃▂▁▁▁▁▁▁</td></tr><tr><td>ensemble_model_train_acc</td><td>▁▇████████</td></tr><tr><td>ensemble_model_train_loss</td><td>█▂▁▁▁▁▁▁▁▁</td></tr><tr><td>ensemble_model_val_acc</td><td>▂▁▇▄▆█▂▄▃▆</td></tr><tr><td>ensemble_model_val_loss</td><td>▂▁▁▂▃▄▆▅▇█</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█▁▂▃▃▄▅▆▆▇█▁▂▃▃▄▅▆▆▇█▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>resnet_model_train_acc</td><td>▁▄▆▇▇█████</td></tr><tr><td>+7</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>effnet_model_train_acc</td><td>0.97798</td></tr><tr><td>effnet_model_train_loss</td><td>0.11536</td></tr><tr><td>effnet_model_val_acc</td><td>0.59746</td></tr><tr><td>effnet_model_val_loss</td><td>1.62109</td></tr><tr><td>ensemble_model_train_acc</td><td>0.98575</td></tr><tr><td>ensemble_model_train_loss</td><td>0.0562</td></tr><tr><td>ensemble_model_val_acc</td><td>0.69915</td></tr><tr><td>ensemble_model_val_loss</td><td>1.2041</td></tr><tr><td>epoch</td><td>10</td></tr><tr><td>resnet_model_train_acc</td><td>0.9525</td></tr><tr><td>+7</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vit_eff_resnet_ensemble</strong> at: <a href='https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble/runs/2r3npx5t' target="_blank">https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble/runs/2r3npx5t</a><br> View project at: <a href='https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble' target="_blank">https://wandb.ai/seerajnuhuumar-shobhit-university/plant-disease-ensemble</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250914_175944-2r3npx5t/logs</code>
